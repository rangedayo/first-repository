# %%
from IPython.display import Image

Image(filename='api 테스트.png', width=500)

# %%
Image(filename='멀티턴.png', width=500)

# %%
Image(filename='초기화.png', width=500)

# %%
Image(filename='wrong-key.png', width=500)

# %%
Image(filename='temperature낮추기.png', width=900)

# %%
Image(filename='temperature높이기.png', width=900)

# %% [markdown]
# ### 회고
#
# 재밌었습니다! 아직 전체적인 구조는 잘 모르겠지만 반복된 특정 부분 나올 때마다 이게 이 말하는 거였구나, 도구 이렇게 사용하는 거였지? 조금씩 알음알음 파악해나가고 있어서 뿌듯합니다 :)
